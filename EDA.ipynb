# %% [markdown]
# ### 15 Categorical Columns, 45 Numerical Columns, 60 Columns Total
# ### Household Head Occupation has 6040 missing values
# ### Household Head Class of Worker has 6040 missing values

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0               Region  Total Food Expenditure  \
# 0       22617                  CAR                   81940
# 1       21389     V - Bicol Region                   26176
# 2       25275  III - Central Luzon                  139920
# 3       25298  III - Central Luzon                  108931
# 4        7780     V - Bicol Region                   61539
#
#         Main Source of Income  Agricultural Household indicator  \
# 0  Enterpreneurial Activities                                 1
# 1     Other sources of Income                                 0
# 2  Enterpreneurial Activities                                 0
# 3               Wage/Salaries                                 0
# 4     Other sources of Income                                 1
#
#    Bread and Cereals Expenditure  Total Rice Expenditure  Meat Expenditure  \
# 0                          44171                   40336              9053
# ...

# %%
print "Rows with missing values {0}".format(df.shape[0] - df.dropna().shape[0])
# Out:
# Rows with missing values 6040

# %%
for col in df.columns:
    print "{0} has {1} missing values".format(col, sum(pd.isnull(df[col])))
# Out:
# Unnamed: 0 has 0 missing values
# Region has 0 missing values
# Total Food Expenditure has 0 missing values
# Main Source of Income has 0 missing values
# Agricultural Household indicator has 0 missing values
# Bread and Cereals Expenditure has 0 missing values
# Total Rice Expenditure has 0 missing values
# Meat Expenditure has 0 missing values
# Total Fish and  marine products Expenditure has 0 missing values
# Fruit Expenditure has 0 missing values
# Vegetables Expenditure has 0 missing values
# Restaurant and hotels Expenditure has 0 missing values
# Alcoholic Beverages Expenditure has 0 missing values
# Tobacco Expenditure has 0 missing values
# Clothing, Footwear and Other Wear Expenditure has 0 missing values
# Housing and water Expenditure has 0 missing values
# Imputed House Rental Value has 0 missing values
# Medical Care Expenditure has 0 missing values
# Transportation Expenditure has 0 missing values
# Communication Expenditure has 0 missing values
# ...

# %%
print "Total rows {0}".format(len(df))
# Out:
# Total rows 33235

# %%
df['Total Household Income'] = df['Total Household Income'] / 1e3
df.describe()
# Out:
#          Unnamed: 0  Total Food Expenditure  Agricultural Household indicator  \
# count  33235.000000            33235.000000                      33235.000000
# mean   20736.223800            85056.056025                          0.430510
# std    11987.166337            51581.403283                          0.676381
# min        0.000000             2947.000000                          0.000000
# 25%    10369.500000            50880.500000                          0.000000
# 50%    20715.000000            73024.000000                          0.000000
# 75%    31094.500000           105529.000000                          1.000000
# max    41543.000000           827565.000000                          2.000000
#
#        Bread and Cereals Expenditure  Total Rice Expenditure  \
# count                   33235.000000            33235.000000
# mean                    25108.306665            18175.818745
# std                     13528.942321            11822.221779
# ...

# %% [markdown]
# ### Distribution of household incomes

# %%
g = sns.distplot(df['Total Household Income'], bins=30, kde=False, rug=False);
g.set(xlim=(0, 2000))

plt.xlabel('Total Household Income (Thousands of Pesos)')
plt.ylabel('Number of Households')
plt.title('Distribution of Total Household Income in Thousands of Pesos')
plt.show()

g.get_figure().savefig('income_histogram.png')

# %% [markdown]
# ### How much does a Filipino family spend on food?

# %%
g = sns.distplot(df['Total Food Expenditure'] / 1e3, kde=False, rug=False)
plt.xlabel('Yearly Total Food Expenditure in Thousands of Pesos')
plt.ylabel('Number of Families')
plt.title('Yearly Food Expenditure of Filipino Families')
plt.show()
g.get_figure().savefig('expenditure_histogram.png')

# %%
cols = ['Bread and Cereals Expenditure', 'Total Rice Expenditure', 'Meat Expenditure', 
        'Total Fish and  marine products Expenditure', 'Fruit Expenditure', 'Vegetables Expenditure']

for col in cols:
    g = sns.distplot(df[col] / 1e5, kde=False, rug=False)
    g.set(xlim=(0, 1))
    plt.show()

# %%
df = pd.read_csv('train.csv')
ax = sns.regplot(x="Total Food Expenditure", y="Total Household Income", data=df)
plt.xlabel('Yearly Total Food Expenditure (Pesos)')
plt.ylabel('Household Income (Pesos)')
plt.title('Effect of Yearly Total Food Expenditure on Household Income')
plt.show()
ax.get_figure().savefig('food_expenditure_income.png')

# %% [markdown]
# ### How much does a Filipino Family Spend on Leisure?

# %%
df = pd.read_csv('train.csv')
leisure = df['Restaurant and hotels Expenditure'] + df['Alcoholic Beverages Expenditure'] + \
        df['Tobacco Expenditure'] + df['Clothing, Footwear and Other Wear Expenditure'] + \
        df['Special Occasions Expenditure']

# %%
ax = sns.regplot(x=leisure, y=df["Total Household Income"])
plt.xlabel('Yearly Total Leisure Expenditure (Pesos)')
plt.ylabel('Household Income (Pesos)')
plt.title('Effect of Yearly Total Leisure Expenditure on Household Income')
plt.show()
ax.get_figure().savefig('leisure_expenditure_income.png')

# %% [markdown]
# ### How much does a family spend on housing?

# %%
df = pd.read_csv('train.csv')
ax = sns.regplot(x="Housing and water Expenditure", y="Total Household Income", data=df)
plt.xlabel('Yearly Total Housing and water Expenditure (Pesos)')
plt.ylabel('Household Income (Pesos)')
plt.title('Effect of Housing and water Expenditure on Household Income')
plt.show()
ax.get_figure().savefig('Housing_and_water_Expenditure_income.png')

# %%
numerics = []
categorical = []

for col in df:
    if((df[col].dtype == np.float64 or df[col].dtype == np.int64) and col != 'Unnamed: 0'):
        numerics.append(col)
        
    else:
        categorical.append(col)
        
categorical_df = df[categorical]
numeric_df = df[numerics]

# %%
numeric_df.columns
# Out:
# Index([u'Total Food Expenditure', u'Agricultural Household indicator',
#        u'Bread and Cereals Expenditure', u'Total Rice Expenditure',
#        u'Meat Expenditure', u'Total Fish and  marine products Expenditure',
#        u'Fruit Expenditure', u'Vegetables Expenditure',
#        u'Restaurant and hotels Expenditure',
#        u'Alcoholic Beverages Expenditure', u'Tobacco Expenditure',
#        u'Clothing, Footwear and Other Wear Expenditure',
#        u'Housing and water Expenditure', u'Imputed House Rental Value',
#        u'Medical Care Expenditure', u'Transportation Expenditure',
#        u'Communication Expenditure', u'Education Expenditure',
#        u'Miscellaneous Goods and Services Expenditure',
#        u'Special Occasions Expenditure',
#        u'Crop Farming and Gardening expenses',
#        u'Total Income from Entrepreneurial Acitivites', u'Household Head Age',
#        u'Total Number of Family members',
#        u'Members with age less than 5 year old',
# ...

# %%
numeric_df['Total number of family members employed'].describe()
# Out:
# count    33235.000000
# mean         1.270648
# std          1.149039
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          8.000000
# Name: Total number of family members employed, dtype: float64

# %%
numeric_df['Total Number of Family members'].describe()
# Out:
# count    33235.000000
# mean         4.632676
# std          2.280119
# min          1.000000
# 25%          3.000000
# 50%          4.000000
# 75%          6.000000
# max         26.000000
# Name: Total Number of Family members, dtype: float64

# %%
p = numeric_df['Total number of family members employed'] / numeric_df['Total Number of Family members']
p.describe()
# Out:
# count    33235.000000
# mean         0.295946
# std          0.274422
# min          0.000000
# 25%          0.000000
# 50%          0.250000
# 75%          0.500000
# max          4.000000
# dtype: float64

# %%
numeric_df.head()
# Out:
#    Total Food Expenditure  Agricultural Household indicator  \
# 0                   81940                                 1
# 1                   26176                                 0
# 2                  139920                                 0
# 3                  108931                                 0
# 4                   61539                                 1
#
#    Bread and Cereals Expenditure  Total Rice Expenditure  Meat Expenditure  \
# 0                          44171                   40336              9053
# 1                          14477                   13067               722
# 2                          31053                   21720             12005
# 3                          41374                   29008             12250
# 4                          23758                   19656              2496
#
#    Total Fish and  marine products Expenditure  Fruit Expenditure  \
# 0                                         4499               5245
# ...

# %%
categorical_df.head()
# Out:
#    Unnamed: 0               Region       Main Source of Income  \
# 0       22617                  CAR  Enterpreneurial Activities
# 1       21389     V - Bicol Region     Other sources of Income
# 2       25275  III - Central Luzon  Enterpreneurial Activities
# 3       25298  III - Central Luzon               Wage/Salaries
# 4        7780     V - Bicol Region     Other sources of Income
#
#   Household Head Sex Household Head Marital Status  \
# 0               Male                       Married
# 1               Male                       Married
# 2               Male                       Married
# 3               Male                       Married
# 4               Male                       Married
#
#   Household Head Highest Grade Completed  \
# 0                    Elementary Graduate
# 1                     No Grade Completed
# 2                   High School Graduate
# 3                Second Year High School
# 4                   High School Graduate
#
# ...

# %%
len(categorical_df.columns)
# Out:
# 16

# %%
for column in categorical_df:
    print "{0} has {1} unique values".format(column, len(np.unique(categorical_df[column])))
# Out:
# Unnamed: 0 has 33235 unique values
# Region has 17 unique values
# Main Source of Income has 3 unique values
# Household Head Sex has 2 unique values
# Household Head Marital Status has 6 unique values
# Household Head Highest Grade Completed has 46 unique values
# Household Head Job or Business Indicator has 2 unique values
# Household Head Occupation has 370 unique values
# Household Head Class of Worker has 8 unique values
# Type of Household has 3 unique values
# Type of Building/House has 6 unique values
# Type of Roof has 7 unique values
# Type of Walls has 6 unique values
# Tenure Status has 8 unique values
# Toilet Facilities has 8 unique values
# Main Source of Water Supply has 11 unique values
# //anaconda/lib/python2.7/site-packages/numpy/lib/arraysetops.py:200: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
# ...

# %%
sorted(np.unique(categorical_df['Tenure Status']))
# Out:
# ['Not Applicable',
#  'Own house, rent lot',
#  'Own house, rent-free lot with consent of owner',
#  'Own house, rent-free lot without consent of owner',
#  'Own or owner-like possession of house and lot',
#  'Rent house/room including lot',
#  'Rent-free house and lot with consent of owner',
#  'Rent-free house and lot without consent of owner']

# %%
"""Household Head Class of Worker_Employer in own family-operated farm or business, 
Household Head Class of Worker_Self-employed wihout any employee, 
Household Head Class of Worker_Worked for government/government corporation, 
Household Head Class of Worker_Worked for private establishment, 
Household Head Class of Worker_Worked for private household"""
# Out:
# 'Household Head Class of Worker_Employer in own family-operated farm or business, \nHousehold Head Class of Worker_Self-employed wihout any employee, \nHousehold Head Class of Worker_Worked for government/government corporation, \nHousehold Head Class of Worker_Worked for private establishment, \nHousehold Head Class of Worker_Worked for private household'

# %% [markdown]
# ### Adding income levels based on regions
# ### Clustering types of jobs
# ### Groupings for grade: none, elementary, high school, bachelors, masters, program/trade school
# ### Total number of electronics
# ### Total number of motorized vehicles
# ### housing/water expenditure x toilet facility interaction
# ### Percentage of family employed (# employed / total family) + interaction between the two terms
